# %% [markdown]
# <a href="https://colab.research.google.com/github/Abinaya0209/full_stack_classroom_august_2019/blob/master/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4f8a6a42-6808-4b4b-aa42-2c64ca5a12b6" name="files[]" multiple disabled />
#      <output id="result-4f8a6a42-6808-4b4b-aa42-2c64ca5a12b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ReflectionRemoval-master.zip to ReflectionRemoval-master.zip
# ...

# %%
! unzip /content/ReflectionRemoval-master.zip
# Out:
# Archive:  /content/ReflectionRemoval-master.zip
# 1890c9ef1a6c3bfb61ac76603196c97c64d8543b
#    creating: ReflectionRemoval-master/
#   inflating: ReflectionRemoval-master/.gitignore
#   inflating: ReflectionRemoval-master/README.md
#    creating: ReflectionRemoval-master/dev_images/
#    creating: ReflectionRemoval-master/dev_images/blended/
#  extracting: ReflectionRemoval-master/dev_images/blended/.gitkeep
#    creating: ReflectionRemoval-master/dev_images/transmission/
#  extracting: ReflectionRemoval-master/dev_images/transmission/.gitkeep
#   inflating: ReflectionRemoval-master/discriminator.py
#    creating: ReflectionRemoval-master/env/
#   inflating: ReflectionRemoval-master/env/env-mac.yml
#   inflating: ReflectionRemoval-master/env/env-win.yml
#    creating: ReflectionRemoval-master/logs/
#  extracting: ReflectionRemoval-master/logs/.gitkeep
#   inflating: ReflectionRemoval-master/model.py
#    creating: ReflectionRemoval-master/models/
# ...

# %%
! python3 /content/ReflectionRemoval-master/discriminator.py
# Out:
# 2020-05-09 15:33:26.310578: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1

# %%
! python3 /content/ReflectionRemoval-master/model.py
# Out:
# 2020-05-09 15:34:36.041942: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "/content/ReflectionRemoval-master/model.py", line 1, in <module>
#     import tensorflow.contrib.slim as slim
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
pip install tensorflow==1.13.2
# Out:
# ...
#      |████████████████████████████████| 92.6MB 62kB/s
# ...
#      |████████████████████████████████| 3.2MB 43.1MB/s
# ...
#      |████████████████████████████████| 368kB 45.2MB/s
# ...
#   Found existing installation: tensorboard 2.2.1
#     Uninstalling tensorboard-2.2.1:
#       Successfully uninstalled tensorboard-2.2.1
#   Found existing installation: tensorflow-estimator 2.2.0
#     Uninstalling tensorflow-estimator-2.2.0:
#       Successfully uninstalled tensorflow-estimator-2.2.0
#   Found existing installation: tensorflow 2.2.0rc4
#     Uninstalling tensorflow-2.2.0rc4:
#       Successfully uninstalled tensorflow-2.2.0rc4
# ...

# %%
! python3 /content/ReflectionRemoval-master/model.py
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from google.colab import files 
files.upload()
# Out:
#      <input type="file" id="files-25c9f85f-7f72-4323-b74f-47bd5a1d1e4a" name="files[]" multiple disabled />
#      <output id="result-25c9f85f-7f72-4323-b74f-47bd5a1d1e4a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving imagenet-vgg-verydeep-19.mat to imagenet-vgg-verydeep-19.mat
